# %% [markdown]
# <a href="https://colab.research.google.com/github/nouramar228-cyber/intermediate-ml-practice-solutions/blob/main/KNN_PCA_Speed_and_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task**
#
# Your task is to compare a default KNeighborsClassifier's speed and performance for a non-PCA dataset and a PCA dataset.
# 1. Load the Data
# This dataset is a modified version of the NHANES dataset found on Kaggle. Download the data [here](https://drive.google.com/file/d/1CE2giLLTp0Cjn0bn9hmtCWIxGZf8_uO1/view?usp=sharing).
# 2. Preprocess the Data
# 3. Model - No PCA
# 4. Transform the data with PCA
# 5. Model - With PCA
# 6. Compare the models
# * In a markdown cell at the end of
# your notebook, answer the following questions:
#
#   * Q1. How many features were used in the first model, and how many PCs were used in the PCA model?
#   * Q2. Which model performed the best on the test set?
#   * Q3. Which model was the fastest at making predictions?

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline

pd.set_option('display.max_columns',200)
pd.set_option("display.max_info_rows", 800)
pd.set_option('display.max_info_columns',800)

from sklearn import set_config
set_config(transform_output='pandas')

# %% [markdown]
# Define Custom Functions

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def classification_metrics(y_true, y_pred, label='',
                           output_dict=False, figsize=(8,4),
                           normalize='true', cmap='Blues',
                           colorbar=False):
    # Get the classification report
    report = classification_report(y_true, y_pred)
    ## Print header and report
    header = "-"*70
    print(header, f" Classification Metrics: {label}", header, sep='\n')
    print(report)
    ## CONFUSION MATRICES SUBPLOTS
    fig, axes = plt.subplots(ncols=2, figsize=figsize)
    # create a confusion matrix  of raw counts
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=None, cmap='gist_gray', colorbar=colorbar,
                ax = axes[0],);
    axes[0].set_title("Raw Counts")
    # create a confusion matrix with the test data
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=normalize, cmap=cmap, colorbar=colorbar,
                ax = axes[1]);
    axes[1].set_title("Normalized Confusion Matrix")
    # Adjust layout and show figure
    fig.tight_layout()
    plt.show()
    # Return dictionary of classification_report
    if output_dict==True:
        report_dict = classification_report(y_true, y_pred, output_dict=True)
        return report_dict


def evaluate_classification(model, X_train, y_train, X_test, y_test,
                         figsize=(6,4), normalize='true', output_dict = False,
                            cmap_train='Blues', cmap_test="Reds",colorbar=False):
    # Get predictions for training data
    y_train_pred = model.predict(X_train)
    # Call the helper function to obtain regression metrics for training data
    results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
                                     output_dict=True, figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_train,
                                     label='Training Data')
    print()
    # Get predictions for test data
    y_test_pred = model.predict(X_test)
    # Call the helper function to obtain regression metrics for test data
    results_test = classification_metrics(y_test, y_test_pred, #verbose = verbose,
                                  output_dict=True,figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_test,
                                    label='Test Data' )
    if output_dict == True:
        # Store results in a dataframe if ouput_frame is True
        results_dict = {'train':results_train,
                    'test': results_test}
        return results_dict

# %% [markdown]
# Load the Dataset

# %%
fpath ='/content/drive/MyDrive/AXSOSACADEMY/AXSOSACADEMY/05-IntermediateML/Week17/Data/NHANES_Diet_Diabetes_Risk.xls.csv'
df = pd.read_csv(fpath)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6643 entries, 0 to 6642
# Data columns (total 169 columns):
#  #    Column         Dtype
# ---   ------         -----
#  0    SEQN           int64
#  1    WTDRD1         float64
#  2    WTDR2D         float64
#  3    DR1DRSTZ       int64
#  4    DR1EXMER       float64
#  5    DRABF          float64
#  6    DRDINT         float64
#  7    DR1DBIH        float64
#  8    DR1DAY         float64
#  9    DR1LANG        float64
#  10   DR1MNRSP       float64
#  11   DR1HELPD       float64
#  12   DBQ095Z        float64
#  13   DBD100         float64
#  14   DRQSPREP       float64
#  15   DR1STY         float64
#  16   DR1SKY         float64
#  17   DRQSDIET       float64
#  18   DRQSDT1        float64
#  19   DRQSDT2        float64
#  20   DRQSDT3        float64
#  21   DRQSDT4        float64
#  22   DRQSDT5        float64
#  23   DRQSDT6        float64
#  24   DRQSDT7        float64
#  25   DRQSDT8        float64
# ...

# %% [markdown]
# Prepare Dataset for Machine Learning.

# %%
df.dtypes.value_counts()
# Out:
# float64    166
# int64        3
# Name: count, dtype: int64

# %%
#Set SEQN as the index
df = df.set_index('SEQN')

# %%
df['Diabetes_Risk'].value_counts()
# Out:
# Diabetes_Risk
# 0    5452
# 2     604
# 1     587
# Name: count, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(432597)

# %% [markdown]
# Define X and y

# %%
y = df['Diabetes_Risk']
X = df.drop(columns='Diabetes_Risk')

# %% [markdown]
# Train Test Split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=321)
X_train.head()
# Out:
#              WTDRD1        WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  DR1DBIH  \
# SEQN
# 74781  34584.687590      0.000000         1      49.0    2.0     1.0     20.0
# 76977  15205.564340  24452.373790         1       2.0    2.0     2.0      9.0
# 79530   4940.540826  13796.381440         1      49.0    2.0     2.0     23.0
# 74171   5061.660951   3885.556268         1      49.0    2.0     2.0     11.0
# 83046  16431.835630  12058.654180         1      59.0    2.0     2.0      9.0
#
#        DR1DAY  DR1LANG  DR1MNRSP  DR1HELPD  DBQ095Z  DBD100  DRQSPREP  DR1STY  \
# SEQN
# 74781     5.0      1.0       1.0      13.0      1.0     1.0       4.0     2.0
# 76977     5.0      1.0       1.0      13.0      1.0     3.0       4.0     1.0
# 79530     6.0      1.0       1.0      13.0      1.0     2.0       3.0     2.0
# 74171     7.0      1.0       1.0      13.0      2.0     1.0       2.0     2.0
# 83046     6.0      1.0       1.0      13.0      4.0     NaN       2.0     2.0
#
# ...

# %% [markdown]
# Scale Data

# %%
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()
X_train_imp = imputer.fit_transform(X_train)
X_test_imp = imputer.transform(X_test)
X_train_tf = scaler.fit_transform(X_train_imp)
X_test_tf = scaler.transform(X_test_imp)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['DRQSDT5']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['DRQSDT5']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(

# %%
knn = KNeighborsClassifier()

knn.fit(X_train_tf, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Record prediction time
# %%time
preds = knn.predict(X_test_tf)
# Out:
# CPU times: user 97 ms, sys: 0 ns, total: 97 ms
# Wall time: 96.9 ms

# %%
evaluate_classification(knn, X_train_tf,y_train, X_test_tf, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      4106
#            1       0.59      0.05      0.09       430
#            2       0.62      0.04      0.07       446
#
#     accuracy                           0.83      4982
#    macro avg       0.68      0.36      0.35      4982
# weighted avg       0.79      0.83      0.76      4982
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      1346
#            1       0.30      0.02      0.04       157
#            2       0.11      0.01      0.01       158
#
# ...

# %% [markdown]
# PCA

# %%
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train_tf)
X_test_pca = pca.transform(X_test_tf)

# %%
# Number of principal components
print("Original Number of Features:", X_train_tf.shape[1])
print("Number of Principal Components:", X_train_pca.shape[1])
# Out:
# Original Number of Features: 166
# Number of Principal Components: 99

# %%
knn_pca = KNeighborsClassifier()
knn_pca.fit(X_train_pca,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Record prediction time
# %%time
preds_pca = knn_pca.predict(X_test_pca)
# Out:
# CPU times: user 161 ms, sys: 0 ns, total: 161 ms
# Wall time: 129 ms

# %%
evaluate_classification(knn_pca, X_train_pca,y_train, X_test_pca, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      4106
#            1       0.59      0.05      0.09       430
#            2       0.55      0.04      0.07       446
#
#     accuracy                           0.83      4982
#    macro avg       0.66      0.36      0.35      4982
# weighted avg       0.79      0.83      0.76      4982
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      1346
#            1       0.50      0.04      0.07       157
#            2       0.11      0.01      0.01       158
#
# ...

# %% [markdown]
# # Model Comparison
#
# ## Q1. How many features were used in the first model, and how many PCs were used in the PCA model?
#
# - The first KNN model used all original features from the dataset.
# - The PCA model reduced the features to a smaller number of Principal Components while still preserving 95% of the variance.
#
# ## Q2. Which model performed the best on the test set?
#
# - Compare the Accuracy, F1-score
# - The KNN model with the PCA slightly better on the test set.
# - It achieved higher accuracy and better macro average scores compared to the non-PCA model.
#
#
#
# ## Q3. Which model was the fastest at making predictions?
#
# - Compare the prediction times from the %%time outputs.
# - The PCA model predicts faster because it uses fewer dimensions.
